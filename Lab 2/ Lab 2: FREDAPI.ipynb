# %% [markdown]
# <a href="https://colab.research.google.com/github/emcgeever-husky/Econ3916/blob/main/Lab%202/%20Lab%202%3A%20FREDAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FRED API initializing
# !pip install fredapi

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from fredapi import Fred

# %%
# Authenticate
# Replace the string below with YOUR unique API key from fred.stlouisfed.org
fred = Fred(api_key='20a0da7e80f594a582f23d5a97a2bc27')
